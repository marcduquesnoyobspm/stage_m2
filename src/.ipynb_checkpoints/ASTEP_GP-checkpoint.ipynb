# %%
# %matplotlib notebook

# %%
import autograd.numpy as np
import matplotlib.pyplot as plt
import celerite
from celerite import terms
import emcee
import corner
import pandas as pd
from scipy import signal
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\h5py\__init__.py:72: UserWarning: h5py is running against HDF5 1.10.2 when it was built against 1.10.3, this may cause problems
#   '{0}.{1}.{2}'.format(*version.hdf5_built_version_tuple)

# %%
bnds = np.array([3320,3340,3492,3494,3666,3668,3711,3712,3713,3768,3769,3770,3771,3772,3773,3774,3849,3905,4007,4035,4036,4038,4039,4060,4093,4094,4095,4206,4207,4208,4226,4227,4228,4229,4230,4231,4238,4239,4242,4243,4244,4525,4786,4787,4789,4827,4828,4829,4905,4906,4908,4909,4921,4922,4923,4924])
groups_bnds = np.array([3320,3340,3492,3666,3711,3768,3850,3905,4007,4035,4060,4093,4206,4226,4238,4525,4786,4827,4905,4921,4924])
indexes = np.array([])

for i in range(len(groups_bnds)) :
    index = np.argwhere(groups_bnds[i] == bnds)
    indexes = np.append(indexes,index)
    
indexes = np.ndarray.flatten(np.array(indexes)).astype(int)

print(indexes)

print(bnds[indexes])
# Out:
# [ 0  1  2  4  6  9 17 18 19 23 24 27 30 36 41 42 45 48 52 55]
# [3320 3340 3492 3666 3711 3768 3905 4007 4035 4060 4093 4206 4226 4238
#  4525 4786 4827 4905 4921 4924]

# %%
### ASTEP data import ###
data = pd.read_csv("betapic_astep_2017.csv")
print(data)
data = data.drop(data[(data["FLAG"]==0) & (data["SUNELEV"] > -13)].index)
# Out:
#                  BJD     FCAL0     FCAL1     FCAL2     FCAL3  SUNELEV  \
# 0       57828.033191  0.999368  0.997744  0.997744  0.986043  -8.2478
# 1       57828.034532  0.999062  0.997438  0.997438  0.985741  -8.3393
# 2       57828.035872  0.999055  0.997431  0.997431  0.985734  -8.4301
# 3       57828.037204  0.995737  0.994119  0.994119  0.982460  -8.5194
# 4       57828.038529  0.995420  0.993802  0.993802  0.982147  -8.6075
# ...              ...       ...       ...       ...       ...      ...
# 106495  58022.320816  0.982556  0.995286  1.000116  0.995286  -6.0849
# 106496  58022.321666  0.982197  0.994922  0.999751  0.994922  -6.0151
# 106497  58022.322514  0.980829  0.993536  0.998358  0.993536  -5.9457
# 106498  58022.323292  0.977350  0.990012  0.994816  0.990012  -5.8819
# 106499  58022.323989  0.975282  0.987918  0.992712  0.987918  -5.8245
#
#         AIRMASS      SKY  FLAG
# 0        1.1461   5319.0   1.0
# 1        1.1473   4837.0   1.0
# 2        1.1485   4401.0   1.0
# 3        1.1497   4013.0   1.0
# 4        1.1509   3664.0   1.0
# ...         ...      ...   ...
# 106495   1.1109  20511.0   1.0
# 106496   1.1105  22328.0   1.0
# 106497   1.1101  24320.0   1.0
# 106498   1.1097  26319.0   1.0
# 106499   1.1094  28337.0   1.0
#
# [106500 rows x 9 columns]

# %%
index = data["BJD"].loc[(data["BJD"] > 57910) & (data["BJD"] < 57918)].index
time = (data["BJD"].loc[index].values)
print(time[-1])
time -= time[0]
flux = data["FCAL1"].values
flux = flux[index]-np.mean(flux)
plt.figure(figsize=(5,3))
for i in range(10):
    index = np.argwhere((time > i*0.7) & (time < (i+1)*0.7))
    plt.scatter(time[index] - time[index[0]],flux[index] - i*0.02,s=1,c='k')
    print(57910 + time[index[-1]])
#plt.plot(data["BJD"].values,data["FCAL1"].values)
# plt.plot(time,flux)
# Out:
# 57917.67030669999
# <img src="data:image/png;base64,..." width="499.9999891627921">
# [57910.6996593]
# [57911.399127]
# [57912.0995344]
# [57912.7990339]
# [57913.4999234]
# [57914.1989912]
# [57914.8999798]
# [57915.599822]
# [57916.2998499]
# [57916.9997158]

# %%
time = data["BJD"].values
flux = data["FCAL1"].values
fs = len(time)/(time[-1] - time[0])
f,pxx = signal.periodogram(flux,fs)
plt.figure(figsize=(9,3))
plt.plot(f,pxx)
# plt.axvline(10,c='r')
plt.xlim([-5,100])
plt.xlabel("Frequency ($d^{-1}$)")
plt.ylabel("PSD")
plt.show()
plt.savefig("periodogram_astep_full_dataset.png",bbox_inches='tight')
# Out:
# <img src="data:image/png;base64,..." width="899.9999804930258">

# %%
# Fréquence d'échantillonnage
fe = 1/(time[1]-time[0])  # Hz

# Fréquence de nyquist
f_nyq = fe / 2.  # Hz

# Fréquence de coupure
fc = 20  # Hz

# Préparation du filtre de Butterworth en passe-haut
b, a = signal.butter(4, fc/f_nyq, 'high', analog=False)

# Application du filtre
flux_filtered = signal.filtfilt(b, a, flux)

# plt.figure()
# for i in range(10):
#     index = np.argwhere((time > i*0.7) & (time < (i+1)*0.7))
#     plt.scatter(time[index] - time[index[0]],flux_filtered[index] - i*0.02,s=1,c='k')
# plt.show()
# np.mean(flux_filtered)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\signal\_arraytools.py:45: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   b = a[a_slice]

# %%
time = data["BJD"].values
flux = data["FCAL1"].values
fs = len(time)/(time[-1] - time[0])
f,pxx = signal.periodogram(flux_filtered,fs)
plt.figure(figsize=(9,3))
plt.plot(f,pxx)
# plt.axvline(10,c='r')
plt.xlim([20,80])
plt.xlabel("Frequency ($d^{-1}$)")
plt.ylabel("PSD")
plt.show()
plt.savefig("periodogram_astep_full_dataset_filtered.png",bbox_inches='tight')
# Out:
# <img src="data:image/png;base64,..." width="899.9999804930258">

# %%
# class CustomTerm(terms.Term):
#     parameter_names = ("log_a", "log_b", "log_c", "log_P")

#     def get_real_coefficients(self, params):
#         log_a, log_b, log_c, log_P = params
#         b = np.exp(log_b)
#         return (
#             np.exp(log_a) * (1.0 + b) / (2.0 + b), np.exp(log_c),
#         )

#     def get_complex_coefficients(self, params):
#         log_a, log_b, log_c, log_P = params
#         b = np.exp(log_b)
#         return (
#             np.exp(log_a) / (2.0 + b), 0.0,
#             np.exp(log_c), 2*np.pi*np.exp(-log_P),
#         )

# %%
### GP Model ###
bounds = dict(log_S0= (None,None), log_Q = (None,None), log_omega0 = (5,7))
kernel = terms.SHOTerm(log_S0=7., log_Q=2., log_omega0=5.7,bounds=bounds)

gp = celerite.GP(kernel,mean=0.0)
gp.compute(time,yerr=1e-3)

print("Initial log likelihood: {0}".format(gp.log_likelihood(flux_filtered)))
print("parameter_dict:\n{0}\n".format(gp.get_parameter_dict()))
# Out:
# Initial log likelihood: -37296.28854199102
# parameter_dict:
# OrderedDict([('kernel:log_S0', 7.0), ('kernel:log_Q', 2.0), ('kernel:log_omega0', 5.7)])

# %%
x = np.linspace(np.min(time),np.max(time),15000)
pred_mean, pred_var = gp.predict(flux_filtered, x, return_var=True)
pred_std = np.sqrt(pred_var)

# %%
color = "#ff7f0e"
#plt.scatter(time,flux,c="r",s=1)
plt.figure(figsize=(9,3))
plt.errorbar(time,flux_filtered,yerr=0,fmt=".r",capsize=0,markersize=1)
plt.plot(x, pred_mean, color=color)
plt.fill_between(x, pred_mean+pred_std, pred_mean-pred_std, color=color, alpha=0.3, edgecolor="none",interpolate=True)
plt.xlabel("x")
plt.ylabel("y")
plt.ylim(np.min(flux_filtered),np.max(flux_filtered))
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="989.9999785423283">

# %%
### Minimize ###
from scipy.optimize import minimize

def neg_log_like(params, y, gp):
    gp.set_parameter_vector(params)
    return -gp.log_likelihood(y)
# extract our initial guess at parameters
# from the celerite kernel and put it in a 
# vector:
p0 = gp.get_parameter_vector()
bounds = gp.get_parameter_bounds()

# run optimization:
results = minimize(neg_log_like, p0, method='L-BFGS-B',bounds=bounds,args=(flux_filtered, gp))
print(results)
print("Final log-likelihood: {0}".format(-results.fun))
print(np.exp(results.x))
print("Parameters: {0}".format(gp.get_parameter_dict()))
gp.set_parameter_vector(results.x)
# Out:
#       fun: -32361.427407117404
#  hess_inv: <3x3 LbfgsInvHessProduct with dtype=float64>
#       jac: array([-8.73114914e-03,  4.36557457e-03, -5.04892523e+02])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 124
#       nit: 17
#    status: 0
#   success: True
#         x: array([-18.5598864,  -0.9451071,   7.       ])
# Final log-likelihood: 32361.427407117404
# [8.70049082e-09 3.88637944e-01 1.09663316e+03]
# Parameters: OrderedDict([('kernel:log_S0', -18.559886396255216), ('kernel:log_Q', -0.9451071031416074), ('kernel:log_omega0', 7.00000001)])

# %%
### Prédiction avec les nouveaux paramètres calculés ###
pred_mean, pred_var = gp.predict(flux_filtered, x, return_var=True)
pred_std = np.sqrt(pred_var)
P = 2*np.pi/np.exp(results.x[2])*60*24
P
# Out:
# 8.250513649710015

# %%
### Plot du posterior du minimize ###
color = "#ff7f0e"
plt.figure(figsize=(9,3))
plt.errorbar(time,flux_filtered,yerr=0,fmt=".r",capsize=0,markersize=1)
plt.plot(x, pred_mean, color=color)
plt.fill_between(x, pred_mean+pred_std, pred_mean-pred_std, color=color, alpha=0.3, edgecolor="none",interpolate=True)
plt.xlabel("x")
plt.ylabel("y")
plt.ylim(np.min(flux_filtered),np.max(flux_filtered))
plt.title("MAP Parameters GP fit")
plt.show()
# plt.scatter(x,flux - pred_mean,c='k',s=1)
# plt.axhline(y=0,color='k')
# plt.title("Residuals")
# plt.show()
# Out:
# <img src="data:image/png;base64,..." width="899.9999804930258">

# %%
### Définition de la likelihood ###
def log_likelihood(params,time,flux):
    gp.set_parameter_vector(params)
    ll = gp.log_likelihood(flux)
    return ll if np.isfinite(ll) else -np.inf

# %%
### Définition du prior (uniforme) ###
def log_prior(params):
    if ((-20 < params[0] < 10) and (-10 < params[1] < 10) and (5 < params[2] < 10)) :
        return 0
    return -np.inf

# %%
### Définition du posterior ###
def log_probability(params,time,flux):
    lp = log_prior(params)
    if not np.isfinite(lp):
        return -np.inf
    return lp + log_likelihood(params,time,flux) if np.isfinite(lp) else -np.inf

# %%
### MCMC ###
initial = np.array(results.x)
ndim, nwalkers = len(initial), 128
sampler = emcee.EnsembleSampler(nwalkers, ndim, log_probability,args=(time,flux_filtered))

print("Running burn-in...")
p0 = initial + 1e-8 * np.random.randn(nwalkers, ndim)
p0, lp, _ = sampler.run_mcmc(p0, 500,progress=True)

print("Running production...")
sampler.reset()
sampler.run_mcmc(p0, 5000,progress=True)
print("Finished")
# Out:
# Running burn-in...
# 100%|██████████| 500/500 [01:46<00:00,  4.71it/s]
# Running production...
# 100%|██████████| 5000/5000 [17:28<00:00,  4.77it/s]
# Finished

# %%
print("Final MCMC Parameters: {0}".format(gp.get_parameter_dict()))
print("Final MCMC log likelihood: {0}".format(gp.log_likelihood(flux_filtered)))
# Out:
# Final MCMC Parameters: OrderedDict([('kernel:log_S0', -18.98432953837564), ('kernel:log_Q', -2.79852795369871), ('kernel:log_omega0', 9.106109219676325)])
# Final MCMC log likelihood: 32537.246863707656

# %%
# Plot the data.

# Plot 24 posterior samples.
color = "#ff7f0e"
plt.figure(figsize=(9,3))
plt.plot(time,flux_filtered,c="r")
plt.plot(x, pred_mean, color=color)
plt.fill_between(x, pred_mean+pred_std, pred_mean-pred_std, color=color, alpha=0.3, edgecolor="none",interpolate=True)
plt.xlabel("x")
plt.ylabel("Flux")
plt.ylim(np.min(flux_filtered),np.max(flux_filtered))
plt.title("GP fit after MCMC run")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="899.9999804930258">

# %%
w = np.exp(gp.get_parameter_vector())
print(w)
f = w[2]/(2*np.pi)
f
# Out:
# [5.69128637e-09 6.08996438e-02 9.01017001e+03]
# 1434.0130955018262

# %%
P = 1/f
P*24*60
# Out:
# 1.004174930143214

# %%
# x = np.linspace(1472,1480,10000)
# time = data[:,0][(1472<data[:,0])&(data[:,0]<1480)]
# flux = data[:,1][(1472<data[:,0])&(data[:,0]<1480)]
# flux = (flux - np.mean(flux))/(np.max(flux) - np.mean(flux))
# gp.compute(time,yerr=0.1*flux)
# pred_mean, pred_var = gp.predict(flux, x, return_var=True)
# pred_std = np.sqrt(pred_var)

# %%
# color = "#ff7f0e"
# plt.figure(figsize=(9,3))
# plt.errorbar(time,flux,yerr=0,fmt=".r",capsize=0,markersize=1)
# plt.plot(x, pred_mean, color=color)
# plt.fill_between(x, pred_mean+pred_std, pred_mean-pred_std, color=color, alpha=0.3, edgecolor="none",interpolate=True)
# plt.xlabel("x")
# plt.ylabel("y")
# plt.ylim(np.min(flux),np.max(flux))
# plt.title("MAP Parameters GP fit")
# plt.show()

# %%
plt.figure()
omega = np.exp(np.linspace(np.log(0.1), np.log(10000), 5000))
psd = gp.kernel.get_psd(omega)
plt.plot(omega, psd, color=color)
plt.yscale("log")
plt.xscale("log")
plt.xlabel("$\omega$")
plt.ylabel("$S(\omega)$")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
flat_samples = sampler.get_chain(discard=100, thin=15, flat=True)
print(flat_samples.shape)
labels = ["log(S0)","log(Q)","log(w0)"]
fig = corner.corner(flat_samples, labels=labels, truths=[None,None,np.log(2*np.pi*47.43)])
plt.show()
# Out:
# (41728, 3)
# <img src="data:image/png;base64,..." width="759.999983527444">

# %%
tau = sampler.get_autocorr_time()
print(tau)
# Out:
# [41.26417291 42.33000493 42.4744558 ]

# %%
pred_mean, pred_var = gp.predict(flux, time, return_var=True)
fs = len(time)/(time[-1] - time[0])
f,pxx = signal.periodogram(flux,fs)
plt.figure(figsize=(9,3))
plt.plot(f,pxx)
plt.show()
idx = np.argmax(pxx)

print("freq:", f[idx],"d-1")
print("periode",1/f[idx]*60*24,"min")
# Out:
# <img src="data:image/png;base64,..." width="899.9999804930258">
# freq: 0.0 d-1
# periode inf min
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: RuntimeWarning: divide by zero encountered in double_scalars
#   # Remove the CWD from sys.path while we load stuff.

# %%
pred_mean, pred_var = gp.predict(flux_filtered, time, return_var=True)
color = "#ff7f0e"
plt.figure(figsize=(9,3))
plt.scatter(time,flux_filtered - pred_mean,s=1)
plt.xlabel("x")
plt.ylabel("y")
plt.ylim(np.min(flux_filtered),np.max(flux_filtered))
plt.title("Residuals")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="899.9999804930258">
